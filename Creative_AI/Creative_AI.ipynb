# %% [markdown]
# <a href="https://colab.research.google.com/github/iavishagupta/GFG-21Days21Projects/blob/main/Creative_AI/Creative_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone "https://github.com/AshishJangra27/Face-Generator-with-GAN"
# Out:
# Cloning into 'Face-Generator-with-GAN'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 34 (delta 10), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 160.27 MiB | 15.80 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Updating files: 100% (10/10), done.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
model = "/content/Face-Generator-with-GAN/generator_700.h5"

generator = tf.keras.models.load_model(model, compile=False)

# %%
noise = tf.random.normal([1,100])

with tf.device('/CPU:0'):
    generated_images = generator(noise, training=False)

generated_images = (generated_images + 1) / 2.0

plt.imshow(generated_images[0])
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(127.5), np.float64(127.5), np.float64(-0.5))
